# %%
import yfinance as yf
import pandas as pd


ticker = "^NSEI"


data = yf.download(
    ticker,
    period="5y",
    interval="1d"
)


print(data.head())
print(data.tail())


data.to_csv("NIFTY_50_5_Years.csv")

print("Data saved successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2021-08-09  16258.250000  16320.750000  16179.049805  16281.349609  240500
# 2021-08-10  16280.099609  16359.250000  16202.250000  16274.799805  288000
# 2021-08-11  16282.250000  16338.750000  16162.549805  16327.299805  277900
# 2021-08-12  16364.400391  16375.500000  16286.900391  16303.650391  280200
# 2021-08-13  16529.099609  16543.599609  16376.299805  16385.699219  321900
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2026-08-03  24774.300781  24774.300781  24515.150391  24572.699219  342300
# 2026-08-04  24614.900391  24703.900391  24427.949219  24703.900391  296500
# ...

# %%
import pandas as pd


df = pd.read_csv("NIFTY_50_5_Years.csv", skiprows=[1, 2])


df.columns = ["Date", "Close", "High", "Low", "Open", "Volume"]


df["Date"] = pd.to_datetime(df["Date"])


numeric_columns = ["Close", "High", "Low", "Open", "Volume"]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

price_columns = ["Close", "High", "Low", "Open"]

df[price_columns] = df[price_columns].round(2)


df = df.dropna()


df = df.reset_index(drop=True)


print(df.head())
print(df.info())


df.to_csv("NIFTY_50_5_Years_cleaned.csv",index=False)


print(" data saved successfully!")
# Out:
#         Date     Close      High       Low      Open  Volume
# 0 2021-08-09  16258.25  16320.75  16179.05  16281.35  240500
# 1 2021-08-10  16280.10  16359.25  16202.25  16274.80  288000
# 2 2021-08-11  16282.25  16338.75  16162.55  16327.30  277900
# 3 2021-08-12  16364.40  16375.50  16286.90  16303.65  280200
# 4 2021-08-13  16529.10  16543.60  16376.30  16385.70  321900
# <class 'pandas.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1235 non-null   datetime64[us]
#  1   Close   1235 non-null   float64
#  2   High    1235 non-null   float64
#  3   Low     1235 non-null   float64
#  4   Open    1235 non-null   float64
#  5   Volume  1235 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 58.0 KB
# None
#  data saved successfully!
